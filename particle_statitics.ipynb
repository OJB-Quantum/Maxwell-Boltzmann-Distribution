# %% [markdown]
# <a href="https://colab.research.google.com/github/OJB-Quantum/Maxwell-Boltzmann-Distribution/blob/main/particle_statitics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Constants
k_B = 8.617333262145e-5  # Boltzmann constant in eV/K
T1 = 0  # Temperature in Kelvin. Try out 0K, 100K, and 500K.
E_F = 1.0  # Fermi level (in eV)

# Energy mesh
E_min = 0
E_max = 2
NE = 1000
energy = np.linspace(E_min, E_max, NE)  # Energy range in eV

# Distributions
def fermi_dirac(energy, T, E_F):
    return 1 / (np.exp((energy - E_F) / (k_B * T)) + 1)

def maxwell_boltzmann(energy, T):
    return np.exp(-(energy - E_F) / (k_B * T))

def bose_einstein(energy, T):
    with np.errstate(divide='ignore', invalid='ignore'):
        be_distribution = 1 / (np.exp((energy - E_F) / (k_B * T)) - 1)
        be_distribution[energy == 0] = np.inf  # Handle the case where energy equals zero
    return be_distribution

# Calculate distributions
fd_distribution = fermi_dirac(energy, T1, E_F)
# mb_distribution = maxwell_boltzmann(energy, T)
# be_distribution = bose_einstein(energy, T)
# Out:
# <ipython-input-25-2bb3337c3825>:14: RuntimeWarning: divide by zero encountered in divide
#   return 1 / (np.exp((energy - E_F) / (k_B * T)) + 1)

# %%
plt.rcParams['figure.dpi'] = 500

# Plot distributions
plt.figure(figsize=(10, 6))
plt.plot(energy, fd_distribution, label='Fermi-Dirac', color='blue')
# plt.plot(energy, mb_distribution, label='Maxwell-Boltzmann', color='green')
# plt.plot(energy, be_distribution, label='Bose-Einstein', color='red')

# Labels and Title
plt.xlabel('Energy (eV)')
plt.ylabel('Distribution Function')
plt.title(f'Distribution Functions at T = {T} K, $E_F$ = {E_F} eV')
plt.legend()

# Set y-axis limits from 0 to 3
plt.ylim(0, 3)
# Show plot
plt.grid(True)
plt.show()

# %%
# Constants
k_B = 8.617333262145e-5  # Boltzmann constant in eV/K
T2 = 100  # Temperature in Kelvin. Try out 0K, 100K, and 500K.
E_F = 1.0  # Fermi level (in eV)

# Energy mesh
E_min = 0
E_max = 2
NE = 1000
energy = np.linspace(E_min, E_max, NE)  # Energy range in eV

# Distributions
def fermi_dirac(energy, T, E_F):
    return 1 / (np.exp((energy - E_F) / (k_B * T)) + 1)

def maxwell_boltzmann(energy, T):
    return np.exp(-(energy - E_F) / (k_B * T))

def bose_einstein(energy, T):
    with np.errstate(divide='ignore', invalid='ignore'):
        be_distribution = 1 / (np.exp((energy - E_F) / (k_B * T)) - 1)
        be_distribution[energy == 0] = np.inf  # Handle the case where energy equals zero
    return be_distribution

# Calculate distributions
fd_distribution = fermi_dirac(energy, T2, E_F)
# mb_distribution = maxwell_boltzmann(energy, T)
# be_distribution = bose_einstein(energy, T)

# %%
# Plot distributions
plt.figure(figsize=(10, 6))
plt.plot(energy, fd_distribution, label='Fermi-Dirac', color='blue')
# plt.plot(energy, mb_distribution, label='Maxwell-Boltzmann', color='green')
# plt.plot(energy, be_distribution, label='Bose-Einstein', color='red')

# Labels and Title
plt.xlabel('Energy (eV)')
plt.ylabel('Distribution Function')
plt.title(f'Distribution Functions at T = {T} K, $E_F$ = {E_F} eV')
plt.legend()

# Set y-axis limits from 0 to 3
plt.ylim(0, 3)
# Show plot
plt.grid(True)
plt.show()

# %%
# Constants
k_B = 8.617333262145e-5  # Boltzmann constant in eV/K
T3 = 500  # Temperature in Kelvin. Try out 0K, 100K, and 500K.
E_F = 1.0  # Fermi level (in eV)

# Energy mesh
E_min = 0
E_max = 2
NE = 1000
energy = np.linspace(E_min, E_max, NE)  # Energy range in eV

# Distributions
def fermi_dirac(energy, T, E_F):
    return 1 / (np.exp((energy - E_F) / (k_B * T)) + 1)

def maxwell_boltzmann(energy, T):
    return np.exp(-(energy - E_F) / (k_B * T))

def bose_einstein(energy, T):
    with np.errstate(divide='ignore', invalid='ignore'):
        be_distribution = 1 / (np.exp((energy - E_F) / (k_B * T)) - 1)
        be_distribution[energy == 0] = np.inf  # Handle the case where energy equals zero
    return be_distribution

# Calculate distributions
fd_distribution = fermi_dirac(energy, T3, E_F)
# mb_distribution = maxwell_boltzmann(energy, T)
# be_distribution = bose_einstein(energy, T)

# %%
# Plot distributions
plt.figure(figsize=(10, 6))
plt.plot(energy, fd_distribution, label='Fermi-Dirac', color='blue')
# plt.plot(energy, mb_distribution, label='Maxwell-Boltzmann', color='green')
# plt.plot(energy, be_distribution, label='Bose-Einstein', color='red')

# Labels and Title
plt.xlabel('Energy (eV)')
plt.ylabel('Distribution Function')
plt.title(f'Distribution Functions at T = {T} K, $E_F$ = {E_F} eV')
plt.legend()

# Set y-axis limits from 0 to 3
plt.ylim(0, 3)
# Show plot
plt.grid(True)
plt.show()

# %% [markdown]
# Now, further modify the code to overlap the 3 Fermi distribution results and increase the resolution of the plots and add custom linewidths if desired. -Onri

# %%
# Constants
k_B = 8.617333262145e-5  # Boltzmann constant in eV/K
T1 = 0
T2 = 100
T3 = 500  # Temperature in Kelvin. Try out 0K, 100K, and 500K.
E_F = 1.0  # Fermi level (in eV)

# Energy mesh
E_min = 0
E_max = 2
NE = 1000
energy = np.linspace(E_min, E_max, NE)  # Energy range in eV

# Distributions
def fermi_dirac(energy, T, E_F):
    return 1 / (np.exp((energy - E_F) / (k_B * T)) + 1)

def maxwell_boltzmann(energy, T):
    return np.exp(-(energy - E_F) / (k_B * T))

def bose_einstein(energy, T):
    with np.errstate(divide='ignore', invalid='ignore'):
        be_distribution = 1 / (np.exp((energy - E_F) / (k_B * T)) - 1)
        be_distribution[energy == 0] = np.inf  # Handle the case where energy equals zero
    return be_distribution

# Calculate distributions
fd_distribution1 = fermi_dirac(energy, T1, E_F)
fd_distribution2 = fermi_dirac(energy, T2, E_F)
fd_distribution3 = fermi_dirac(energy, T3, E_F)
# mb_distribution = maxwell_boltzmann(energy, T)
# be_distribution = bose_einstein(energy, T)
# Out:
# <ipython-input-48-78b139f4b5ee>:16: RuntimeWarning: divide by zero encountered in divide
#   return 1 / (np.exp((energy - E_F) / (k_B * T)) + 1)

# %%
# Plot distributions all 3 together.

plt.figure(figsize=(10, 6))
plt.plot(energy, fd_distribution1, label='Fermi-Dirac', color='red')
plt.plot(energy, fd_distribution2, label='Fermi-Dirac', color='green')
plt.plot(energy, fd_distribution3, label='Fermi-Dirac', color='blue')


# Labels and Title
plt.xlabel('Energy (eV)')
plt.ylabel('Distribution Function')
plt.title(f'Distribution Functions at T = {T} K, $E_F$ = {E_F} eV')
plt.legend()

# Set y-axis limits from 0 to 3. It goes from 0 to 3 by default. You can change this from 0 to 1.2 instead for better quality plotting.
plt.ylim(0, 1.2)
# Show plot
plt.grid(True)
plt.show()

# %% [markdown]
# Now, change the Fermi energy to 0 eV instead of 1 and plot for all 3 temperatures.

# %%
# Constants
k_B = 8.617333262145e-5  # Boltzmann constant in eV/K
T1 = 0
T2 = 0.001
T3 = 100
T4 = 500  # Temperature in Kelvin. Try out 0K, 100K, and 500K.
E_F = 0.0  # Fermi level (in eV)

# Energy mesh
E_min = 0
E_max = 2
NE = 1000
energy = np.linspace(E_min, E_max, NE)  # Energy range in eV

# Distributions
def fermi_dirac(energy, T, E_F):
    return 1 / (np.exp((energy - E_F) / (k_B * T)) + 1)

def maxwell_boltzmann(energy, T):
    return np.exp(-(energy - E_F) / (k_B * T))

def bose_einstein(energy, T):
    with np.errstate(divide='ignore', invalid='ignore'):
        be_distribution = 1 / (np.exp((energy - E_F) / (k_B * T)) - 1)
        be_distribution[energy == 0] = np.inf  # Handle the case where energy equals zero
    return be_distribution

# Calculate distributions
# fd_distribution1 = fermi_dirac(energy, T1, E_F)
# fd_distribution2 = fermi_dirac(energy, T2, E_F)
# fd_distribution3 = fermi_dirac(energy, T3, E_F)
# fd_distribution4 = fermi_dirac(energy, T4, E_F)
# mb_distribution = maxwell_boltzmann(energy, T)
be_distribution1 = bose_einstein(energy, T1)
be_distribution2 = bose_einstein(energy, T2)
be_distribution3 = bose_einstein(energy, T3)
be_distribution4 = bose_einstein(energy, T4)
# Out:
# <ipython-input-60-a2a9d6ff78bc>:24: RuntimeWarning: overflow encountered in exp
#   be_distribution = 1 / (np.exp((energy - E_F) / (k_B * T)) - 1)

# %%
# Plot distributions all 3 together.

plt.figure(figsize=(10, 6))
plt.plot(energy, be_distribution1, label='Bose Einstein', color='orange', lw=1)
plt.plot(energy, be_distribution2, label='Bose Einstein', color='red', lw=1)
plt.plot(energy, be_distribution3, label='Bose Einstein', color='green', lw=1)
plt.plot(energy, be_distribution4, label='Bose Einstein', color='blue', lw=1)



# Labels and Title
plt.xlabel('Energy (eV)')
plt.ylabel('Distribution Function')
plt.title(f'Distribution Functions at T = {T} K, $E_F$ = {E_F} eV')
plt.legend()

# Set y-axis limits from 0 to 6.
# Determine by playing with and monitoring the starting point of the plot. You may have to change to a log plot instead or simply include it at the end for comparison.
plt.ylim(0, 6)
# Show plot
plt.grid(True)
plt.show()
